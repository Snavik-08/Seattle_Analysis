# %% [markdown]
# # Analysing Seattle Data Set

# %% [markdown]
# The following EDA uses the Airbnb Data Set that can be found here: https://www.kaggle.com/airbnb/seattle
# Thre questions are investigated within this notebook, namely:
#
# - how much one can expect to pay for an Airbnb accomondation in Seattle and what might affect the price
# - how the availability of accomondations differ depending the time dimension
# - how much revenue one can expect by providing an accomondation in Seattle on Airbnb

# %%
import numpy as np 
import pandas as pd 
import re
import os
import tabulate

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Section 2: Data Understanding

# %%
df_rev = pd.read_csv('reviews.csv')
df_cal = pd.read_csv('calendar.csv')
df_list = pd.read_csv('listings.csv')

# %%
df_rev.head(10)
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0     7202016  38917982  2015-07-19     28943674        Bianca
# 1     7202016  39087409  2015-07-20     32440555         Frank
# 2     7202016  39820030  2015-07-26     37722850           Ian
# 3     7202016  40813543  2015-08-02     33671805        George
# 4     7202016  41986501  2015-08-10     34959538          Ming
# 5     7202016  43979139  2015-08-23      1154501        Barent
# 6     7202016  45265631  2015-09-01     37853266         Kevin
# 7     7202016  46749120  2015-09-13     24445447          Rick
# 8     7202016  47783346  2015-09-21       249583          Todd
# 9     7202016  48388999  2015-09-26     38110731       Tatiana
#
#                                             comments
# 0  Cute and cozy place. Perfect location to every...
# 1  Kelly has a great room in a very central locat...
# 2  Very spacious apartment, and in a great neighb...
# 3  Close to Seattle Center and all it has to offe...
# 4  Kelly was a great host and very accommodating ...
# 5  Kelly was great, place was great, just what I ...
# 6  Kelly was great! Very nice and the neighborhoo...
# 7  hola all bnb erz - Just left Seattle where I h...
# 8  Kelly's place is conveniently located on a qui...
# 9  The place was really nice, clean, and the most...

# %%
df_cal.head(10)
# Out:
#    listing_id        date available   price
# 0      241032  2016-01-04         t  $85.00
# 1      241032  2016-01-05         t  $85.00
# 2      241032  2016-01-06         f     NaN
# 3      241032  2016-01-07         f     NaN
# 4      241032  2016-01-08         f     NaN
# 5      241032  2016-01-09         f     NaN
# 6      241032  2016-01-10         f     NaN
# 7      241032  2016-01-11         f     NaN
# 8      241032  2016-01-12         f     NaN
# 9      241032  2016-01-13         t  $85.00

# %%
df_list.head(10)
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2  3308979  https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
# 3  7421966  https://www.airbnb.com/rooms/7421966  20160104002432   2016-01-04
# 4   278830   https://www.airbnb.com/rooms/278830  20160104002432   2016-01-04
# 5  5956968  https://www.airbnb.com/rooms/5956968  20160104002432   2016-01-04
# 6  1909058  https://www.airbnb.com/rooms/1909058  20160104002432   2016-01-04
# 7   856550   https://www.airbnb.com/rooms/856550  20160104002432   2016-01-04
# 8  4948745  https://www.airbnb.com/rooms/4948745  20160104002432   2016-01-04
# 9  2493658  https://www.airbnb.com/rooms/2493658  20160104002432   2016-01-04
#
#                                   name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
# 3                   Queen Anne Chateau
# 4       Charming craftsman 3 bdm house
# 5      Private unit in a 1920s mansion
# 6      Queen Anne Private Bed and Bath
# 7    Tiny Garden cabin on Queen Anne
# 8     Urban Charm || Downtown || Views
# 9   Airy + Bright Queen Anne Apartment
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# 3  A charming apartment that sits atop Queen Anne...
# 4  Cozy family craftman house in beautiful neighb...
# 5  We're renting out a small private unit of one ...
# 6  Enjoy a quiet stay in our comfortable 1915 Cra...
# 7  Our tiny cabin is private , very quiet and com...
# 8  Nestled in the heart of the city, this space i...
# 9  Beautiful apartment in an extremely safe, quie...
#
#                                                space  \
# 0  Make your self at home in this charming one-be...
# 1  Beautiful, hypoallergenic apartment in an extr...
# 2  Our house is modern, light and fresh with a wa...
# 3                                                NaN
# 4  Cozy family craftman house in beautiful neighb...
# 5  If you include a bit of your background in you...
# 6  Enjoy a quiet stay in our comfortable 1915 Cra...
# 7   This cabin was built with Airbnb in mind, Que...
# 8  Located in the heart of the city, this space i...
# 9  What's special about this place? A beautiful r...
#
#                                          description experiences_offered  \
# 0  Make your self at home in this charming one-be...                none
# 1  Chemically sensitive? We've removed the irrita...                none
# 2  New modern house built in 2013.  Spectacular s...                none
# 3  A charming apartment that sits atop Queen Anne...                none
# 4  Cozy family craftman house in beautiful neighb...                none
# 5  We're renting out a small private unit of one ...                none
# 6  Enjoy a quiet stay in our comfortable 1915 Cra...                none
# 7  Our tiny cabin is private , very quiet and com...                none
# 8  Nestled in the heart of the city, this space i...                none
# 9  Beautiful apartment in an extremely safe, quie...                none
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1  Queen Anne is a wonderful, truly functional vi...
# 2  Upper Queen Anne is a charming neighborhood fu...
# 3                                                NaN
# 4  We are in the beautiful neighborhood of Queen ...
# 5  This part of Queen Anne has wonderful views an...
# 6  Close restaurants, coffee shops and grocery st...
# 7  We are centrally located between Downtown and ...
# 8  Walking Score: 92 4 blocks from Kerry Park Fam...
# 9  Queen Anne is a wonderful, truly functional vi...
#
#                                                notes  \
# 0                                                NaN
# 1  What's up with the free pillows?  Our home was...
# 2  Our house is located just 5 short blocks to To...
# 3                                                NaN
# 4                                          Belltown
# 5  Let me know if you need anything or have sugge...
# 6  The room now has a mini frig to keep your favo...
# 7  There are three rentals in our back yard . If ...
# 8                                                NaN
# 9  What's up with the free pillows?  Our home was...
#
#                                              transit  \
# 0                                                NaN
# 1  Convenient bus stops are just down the block, ...
# 2  A bus stop is just 2 blocks away.   Easy bus a...
# 3                                                NaN
# 4  The nearest public transit bus (D Line) is 2 b...
# 5  The #1 and #2 bus picks up 2-3 blocks away (di...
# 6  The bus goes through the lower Queen Anne neig...
# 7     the "D" line runs out in front of our house .
# 8  Bus stop to downtown directly across the stree...
# 9  Convenient bus stops are just down the block, ...
#
#                                        thumbnail_url  \
# 0                                                NaN
# 1  https://a0.muscache.com/ac/pictures/14409893/f...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  https://a2.muscache.com/ac/pictures/84791950/f...
# 6  https://a2.muscache.com/ac/pictures/26505642/2...
# 7  https://a2.muscache.com/ac/pictures/83538305/d...
# 8  https://a0.muscache.com/ac/pictures/85453284/d...
# 9  https://a2.muscache.com/ac/pictures/33003258/f...
#
#                                           medium_url  \
# 0                                                NaN
# 1  https://a0.muscache.com/im/pictures/14409893/f...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  https://a2.muscache.com/im/pictures/84791950/f...
# 6  https://a2.muscache.com/im/pictures/26505642/2...
# 7  https://a2.muscache.com/im/pictures/83538305/d...
# 8  https://a0.muscache.com/im/pictures/85453284/d...
# 9  https://a2.muscache.com/im/pictures/33003258/f...
#
#                                          picture_url  \
# 0  https://a1.muscache.com/ac/pictures/67560560/c...
# 1  https://a0.muscache.com/ac/pictures/14409893/f...
# 2  https://a2.muscache.com/ac/pictures/b4324e0f-a...
# 3  https://a0.muscache.com/ac/pictures/94146944/6...
# 4  https://a1.muscache.com/ac/pictures/6120468/b0...
# 5  https://a2.muscache.com/ac/pictures/84791950/f...
# 6  https://a2.muscache.com/ac/pictures/26505642/2...
# 7  https://a2.muscache.com/ac/pictures/83538305/d...
# 8  https://a0.muscache.com/ac/pictures/85453284/d...
# 9  https://a2.muscache.com/ac/pictures/33003258/f...
#
#                                       xl_picture_url   host_id  \
# 0                                                NaN    956883
# 1  https://a0.muscache.com/ac/pictures/14409893/f...   5177328
# 2                                                NaN  16708587
# 3                                                NaN   9851441
# 4                                                NaN   1452570
# 5  https://a2.muscache.com/ac/pictures/84791950/f...    326758
# 6  https://a2.muscache.com/ac/pictures/26505642/2...   2497928
# 7  https://a2.muscache.com/ac/pictures/83538305/d...   4016632
# 8  https://a0.muscache.com/ac/pictures/85453284/d...   2166277
# 9  https://a2.muscache.com/ac/pictures/33003258/f...   5177328
#
#                                      host_url      host_name  host_since  \
# 0    https://www.airbnb.com/users/show/956883          Maija  2011-08-11
# 1   https://www.airbnb.com/users/show/5177328         Andrea  2013-02-21
# 2  https://www.airbnb.com/users/show/16708587           Jill  2014-06-12
# 3   https://www.airbnb.com/users/show/9851441          Emily  2013-11-06
# 4   https://www.airbnb.com/users/show/1452570          Emily  2011-11-29
# 5    https://www.airbnb.com/users/show/326758         Andrew  2010-12-25
# 6   https://www.airbnb.com/users/show/2497928  Gary And Beth  2012-05-30
# 7   https://www.airbnb.com/users/show/4016632      Jean-Marc  2012-10-30
# 8   https://www.airbnb.com/users/show/2166277          Aliza  2012-04-18
# 9   https://www.airbnb.com/users/show/5177328         Andrea  2013-02-21
#
#                         host_location  \
# 0  Seattle, Washington, United States
# 1  Seattle, Washington, United States
# 2  Seattle, Washington, United States
# 3  Seattle, Washington, United States
# 4  Seattle, Washington, United States
# 5  Seattle, Washington, United States
# 6  Seattle, Washington, United States
# 7  Seattle, Washington, United States
# 8  Seattle, Washington, United States
# 9  Seattle, Washington, United States
#
#                                           host_about  host_response_time  \
# 0  I am an artist, interior designer, and run a s...  within a few hours
# 1  Living east coast/left coast/overseas.  Time i...      within an hour
# 2  i love living in Seattle.  i grew up in the mi...  within a few hours
# 3                                                NaN                 NaN
# 4  Hi, I live in Seattle, Washington but I'm orig...      within an hour
# 5  I've been fortunate to have had many life expe...                 NaN
# 6  We have lived in the the Queen Anne neighborho...      within an hour
# 7  I am a carpenter at heart , I love music , I p...      within an hour
# 8  I'm a 35 year old professional from Seattle, W...                 NaN
# 9  Living east coast/left coast/overseas.  Time i...      within an hour
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0                96%                 100%                 f
# 1                98%                 100%                 t
# 2                67%                 100%                 f
# 3                NaN                  NaN                 f
# 4               100%                  NaN                 f
# 5                NaN                  NaN                 f
# 6               100%                 100%                 t
# 7               100%                 100%                 t
# 8                NaN                 100%                 f
# 9                98%                 100%                 t
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/ac/users/956883/profil...
# 1  https://a0.muscache.com/ac/users/5177328/profi...
# 2  https://a1.muscache.com/ac/users/16708587/prof...
# 3  https://a2.muscache.com/ac/users/9851441/profi...
# 4  https://a0.muscache.com/ac/users/1452570/profi...
# 5  https://a2.muscache.com/ac/users/326758/profil...
# 6  https://a0.muscache.com/ac/users/2497928/profi...
# 7  https://a1.muscache.com/ac/users/4016632/profi...
# 8  https://a1.muscache.com/ac/users/2166277/profi...
# 9  https://a0.muscache.com/ac/users/5177328/profi...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/ac/users/956883/profil...         Queen Anne
# 1  https://a0.muscache.com/ac/users/5177328/profi...         Queen Anne
# 2  https://a1.muscache.com/ac/users/16708587/prof...         Queen Anne
# 3  https://a2.muscache.com/ac/users/9851441/profi...         Queen Anne
# 4  https://a0.muscache.com/ac/users/1452570/profi...         Queen Anne
# 5  https://a2.muscache.com/ac/users/326758/profil...         Queen Anne
# 6  https://a0.muscache.com/ac/users/2497928/profi...         Queen Anne
# 7  https://a1.muscache.com/ac/users/4016632/profi...         Queen Anne
# 8  https://a1.muscache.com/ac/users/2166277/profi...         Queen Anne
# 9  https://a0.muscache.com/ac/users/5177328/profi...         Queen Anne
#
#    host_listings_count  host_total_listings_count  \
# 0                  3.0                        3.0
# 1                  6.0                        6.0
# 2                  2.0                        2.0
# 3                  1.0                        1.0
# 4                  2.0                        2.0
# 5                  1.0                        1.0
# 6                  1.0                        1.0
# 7                  5.0                        5.0
# 8                  1.0                        1.0
# 9                  6.0                        6.0
#
#                                   host_verifications host_has_profile_pic  \
# 0               ['email', 'phone', 'reviews', 'kba']                    t
# 1  ['email', 'phone', 'facebook', 'linkedin', 're...                    t
# 2   ['email', 'phone', 'google', 'reviews', 'jumio']                    t
# 3  ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 4   ['email', 'phone', 'facebook', 'reviews', 'kba']                    t
# 5   ['email', 'phone', 'facebook', 'reviews', 'kba']                    t
# 6               ['email', 'phone', 'reviews', 'kba']                    t
# 7  ['email', 'phone', 'facebook', 'google', 'link...                    t
# 8  ['email', 'phone', 'facebook', 'linkedin', 're...                    t
# 9  ['email', 'phone', 'facebook', 'linkedin', 're...                    t
#
#   host_identity_verified                                             street  \
# 0                      t      Gilman Dr W, Seattle, WA 98119, United States
# 1                      t  7th Avenue West, Seattle, WA 98119, United States
# 2                      t  West Lee Street, Seattle, WA 98119, United States
# 3                      t  8th Avenue West, Seattle, WA 98119, United States
# 4                      t       14th Ave W, Seattle, WA 98119, United States
# 5                      t  West Comstock Street, Seattle, WA 98119, Unite...
# 6                      t  10th Avenue West, Seattle, WA 98119, United St...
# 7                      t  West Wheeler Street, Seattle, WA 98119, United...
# 8                      t  Queen Anne Avenue North, Seattle, WA 98109, Un...
# 9                      t  7th Avenue West, Seattle, WA 98119, United States
#
#   neighbourhood neighbourhood_cleansed neighbourhood_group_cleansed     city  \
# 0    Queen Anne        West Queen Anne                   Queen Anne  Seattle
# 1    Queen Anne        West Queen Anne                   Queen Anne  Seattle
# 2    Queen Anne        West Queen Anne                   Queen Anne  Seattle
# 3    Queen Anne        West Queen Anne                   Queen Anne  Seattle
# 4    Queen Anne        West Queen Anne                   Queen Anne  Seattle
# 5    Queen Anne        West Queen Anne                   Queen Anne  Seattle
# 6    Queen Anne        West Queen Anne                   Queen Anne  Seattle
# 7    Queen Anne        West Queen Anne                   Queen Anne  Seattle
# 8    Queen Anne        West Queen Anne                   Queen Anne  Seattle
# 9    Queen Anne        West Queen Anne                   Queen Anne  Seattle
#
#   state zipcode   market smart_location country_code        country  \
# 0    WA   98119  Seattle    Seattle, WA           US  United States
# 1    WA   98119  Seattle    Seattle, WA           US  United States
# 2    WA   98119  Seattle    Seattle, WA           US  United States
# 3    WA   98119  Seattle    Seattle, WA           US  United States
# 4    WA   98119  Seattle    Seattle, WA           US  United States
# 5    WA   98119  Seattle    Seattle, WA           US  United States
# 6    WA   98119  Seattle    Seattle, WA           US  United States
# 7    WA   98119  Seattle    Seattle, WA           US  United States
# 8    WA   98109  Seattle    Seattle, WA           US  United States
# 9    WA   98119  Seattle    Seattle, WA           US  United States
#
#     latitude   longitude is_location_exact property_type        room_type  \
# 0  47.636289 -122.371025                 t     Apartment  Entire home/apt
# 1  47.639123 -122.365666                 t     Apartment  Entire home/apt
# 2  47.629724 -122.369483                 t         House  Entire home/apt
# 3  47.638473 -122.369279                 t     Apartment  Entire home/apt
# 4  47.632918 -122.372471                 t         House  Entire home/apt
# 5  47.630525 -122.366174                 t         House     Private room
# 6  47.636605 -122.368519                 t         House     Private room
# 7  47.640161 -122.375856                 t         Cabin     Private room
# 8  47.632410 -122.357216                 t     Apartment     Private room
# 9  47.637492 -122.366889                 t     Apartment  Entire home/apt
#
#    accommodates  bathrooms  bedrooms  beds  bed_type  \
# 0             4        1.0       1.0   1.0  Real Bed
# 1             4        1.0       1.0   1.0  Real Bed
# 2            11        4.5       5.0   7.0  Real Bed
# 3             3        1.0       0.0   2.0  Real Bed
# 4             6        2.0       3.0   3.0  Real Bed
# 5             2        1.0       1.0   1.0  Real Bed
# 6             2        1.0       1.0   1.0  Real Bed
# 7             2        1.0       1.0   1.0  Real Bed
# 8             2        1.0       1.0   1.0  Real Bed
# 9             4        1.0       1.0   1.0  Real Bed
#
#                                            amenities  square_feet    price  \
# 0  {TV,"Cable TV",Internet,"Wireless Internet","A...          NaN   $85.00
# 1  {TV,Internet,"Wireless Internet",Kitchen,"Free...          NaN  $150.00
# 2  {TV,"Cable TV",Internet,"Wireless Internet","A...          NaN  $975.00
# 3  {Internet,"Wireless Internet",Kitchen,"Indoor ...          NaN  $100.00
# 4  {TV,"Cable TV",Internet,"Wireless Internet",Ki...          NaN  $450.00
# 5  {"Wireless Internet","Free Parking on Premises...          NaN  $120.00
# 6  {"Wireless Internet","Free Parking on Premises...          NaN   $80.00
# 7  {"Wireless Internet","Pets live on this proper...          NaN   $60.00
# 8  {TV,"Cable TV",Internet,"Wireless Internet",Ki...          NaN   $90.00
# 9  {TV,Internet,"Wireless Internet",Kitchen,"Free...          NaN  $150.00
#
#   weekly_price monthly_price security_deposit cleaning_fee  guests_included  \
# 0          NaN           NaN              NaN          NaN                2
# 1    $1,000.00     $3,000.00          $100.00       $40.00                1
# 2          NaN           NaN        $1,000.00      $300.00               10
# 3      $650.00     $2,300.00              NaN          NaN                1
# 4          NaN           NaN          $700.00      $125.00                6
# 5      $800.00           NaN              NaN       $40.00                1
# 6      $575.00           NaN          $150.00          NaN                1
# 7      $360.00           NaN          $150.00       $25.00                1
# 8      $500.00     $1,700.00              NaN          NaN                1
# 9    $1,000.00     $3,000.00          $100.00       $40.00                1
#
#   extra_people  minimum_nights  maximum_nights calendar_updated  \
# 0        $5.00               1             365      4 weeks ago
# 1        $0.00               2              90            today
# 2       $25.00               4              30      5 weeks ago
# 3        $0.00               1            1125     6 months ago
# 4       $15.00               1            1125      7 weeks ago
# 5       $30.00               1               6      2 weeks ago
# 6       $10.00               3              14      5 weeks ago
# 7        $0.00               2               7        yesterday
# 8        $0.00               3            1125     5 months ago
# 9        $0.00               2             365            today
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t               14               41               71
# 1                t               13               13               16
# 2                t                1                6               17
# 3                t                0                0                0
# 4                t               30               60               90
# 5                t                0                0               27
# 6                t               20               49               71
# 7                t               22               42               42
# 8                t                6               36               66
# 9                t                6               19               49
#
#    availability_365 calendar_last_scraped  number_of_reviews first_review  \
# 0               346            2016-01-04                207   2011-11-01
# 1               291            2016-01-04                 43   2013-08-19
# 2               220            2016-01-04                 20   2014-07-30
# 3               143            2016-01-04                  0          NaN
# 4               365            2016-01-04                 38   2012-07-10
# 5               302            2016-01-04                 17   2015-06-11
# 6               346            2016-01-04                 58   2014-01-27
# 7               100            2016-01-04                173   2013-01-03
# 8               341            2016-01-04                  8   2015-06-22
# 9               324            2016-01-04                 32   2014-04-27
#
#   last_review  review_scores_rating  review_scores_accuracy  \
# 0  2016-01-02                  95.0                    10.0
# 1  2015-12-29                  96.0                    10.0
# 2  2015-09-03                  97.0                    10.0
# 3         NaN                   NaN                     NaN
# 4  2015-10-24                  92.0                     9.0
# 5  2015-09-28                  95.0                    10.0
# 6  2015-12-07                  99.0                    10.0
# 7  2016-01-01                  97.0                    10.0
# 8  2015-08-17                  97.0                    10.0
# 9  2015-12-20                  97.0                    10.0
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       10.0                   10.0
# 1                       10.0                   10.0
# 2                       10.0                   10.0
# 3                        NaN                    NaN
# 4                        9.0                   10.0
# 5                       10.0                   10.0
# 6                       10.0                   10.0
# 7                       10.0                   10.0
# 8                        9.0                   10.0
# 9                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                     9.0                 10.0
# 1                         10.0                    10.0                 10.0
# 2                         10.0                    10.0                 10.0
# 3                          NaN                     NaN                  NaN
# 4                         10.0                     9.0                  9.0
# 5                         10.0                    10.0                 10.0
# 6                         10.0                    10.0                 10.0
# 7                         10.0                     9.0                 10.0
# 8                          9.0                    10.0                 10.0
# 9                         10.0                    10.0                  9.0
#
#   requires_license  license jurisdiction_names instant_bookable  \
# 0                f      NaN         WASHINGTON                f
# 1                f      NaN         WASHINGTON                f
# 2                f      NaN         WASHINGTON                f
# 3                f      NaN         WASHINGTON                f
# 4                f      NaN         WASHINGTON                f
# 5                f      NaN         WASHINGTON                f
# 6                f      NaN         WASHINGTON                f
# 7                f      NaN         WASHINGTON                f
# 8                f      NaN         WASHINGTON                f
# 9                f      NaN         WASHINGTON                f
#
#   cancellation_policy require_guest_profile_picture  \
# 0            moderate                             f
# 1              strict                             t
# 2              strict                             f
# 3            flexible                             f
# 4              strict                             f
# 5              strict                             f
# 6            moderate                             f
# 7              strict                             t
# 8              strict                             f
# 9              strict                             t
#
#   require_guest_phone_verification  calculated_host_listings_count  \
# 0                                f                               2
# 1                                t                               6
# 2                                f                               2
# 3                                f                               1
# 4                                f                               1
# 5                                f                               1
# 6                                f                               1
# 7                                t                               5
# 8                                f                               1
# 9                                t                               6
#
#    reviews_per_month
# 0               4.07
# 1               1.48
# 2               1.15
# 3                NaN
# 4               0.89
# 5               2.45
# 6               2.46
# 7               4.73
# 8               1.22
# 9               1.55

# %% [markdown]
# ## Section 3: Data Preperation and Data cleaning

# %% [markdown]
# #### Generate a price format adjustment function

# %%
def price_column_to_int(column):
    column = column.apply(str)
    column = column.apply(lambda col_value: re.sub("[\$,]", '', col_value))
    return(column.astype(float))
    
    #return re.sub("[\$,]", '', column).astype(float)

# %% [markdown]
# #### Changing price format

# %%
df_cal["price"] = price_column_to_int(df_cal["price"])
df_list["price"] = price_column_to_int(df_list["price"])
df_list["weekly_price"] = price_column_to_int(df_list["weekly_price"])
df_list["monthly_price"] = price_column_to_int(df_list["monthly_price"])
df_list["security_deposit"] = price_column_to_int(df_list["security_deposit"])
df_list["cleaning_fee"] = price_column_to_int(df_list["cleaning_fee"])

# %% [markdown]
# #### Transform as date format

# %%
df_cal['date'] = pd.to_datetime(df_cal['date'])

# %% [markdown]
# #### Transform nominal variables

# %%
inst_book_values = {"f": 0, "t": 1}
df_list["instant_bookable"] = df_list.instant_bookable.map(inst_book_values)

# %%
df_list['host_response_time_encoded'] = df_list['host_response_time'].map({"within an hour": 0, 
                                                                           "within a few hours": 1,
                                                                           "within a day": 2,
                                                                           "a few days or more":3
                                                                          })

# %%
df_list["host_is_superhost"] = df_list["host_is_superhost"].map({"f": 0, "t": 1})

# %% [markdown]
# #### Remove NaNs from host_total_listings_count

# %%
df_list = df_list.dropna(subset = ["host_total_listings_count"], how ='any')

# %%
df_list.loc[df_list["host_total_listings_count"].isnull(), ]
# Out:
# Empty DataFrame
# Columns: [id, listing_url, scrape_id, last_scraped, name, summary, space, description, experiences_offered, neighborhood_overview, notes, transit, thumbnail_url, medium_url, picture_url, xl_picture_url, host_id, host_url, host_name, host_since, host_location, host_about, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_thumbnail_url, host_picture_url, host_neighbourhood, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, street, neighbourhood, neighbourhood_cleansed, neighbourhood_group_cleansed, city, state, zipcode, market, smart_location, country_code, country, latitude, longitude, is_location_exact, property_type, room_type, accommodates, bathrooms, bedrooms, beds, bed_type, amenities, square_feet, price, weekly_price, monthly_price, security_deposit, cleaning_fee, guests_included, extra_people, minimum_nights, maximum_nights, calendar_updated, has_availability, availability_30, availability_60, availability_90, availability_365, calendar_last_scraped, number_of_reviews, first_review, last_review, review_scores_rating, review_scores_accuracy, review_scores_cleanliness, review_scores_checkin, review_scores_communication, review_scores_location, review_scores_value, requires_license, license, jurisdiction_names, instant_bookable, cancellation_policy, require_guest_profile_picture, require_guest_phone_verification, calculated_host_listings_count, reviews_per_month, host_response_time_encoded]
# Index: []

# %% [markdown]
# #### Change host_total_listings_count as int

# %%
df_list["host_total_listings_count"] = df_list["host_total_listings_count"].astype(int)

# %%
df_cal["price"].isnull().sum()
# Out:
# 459028

# %% [markdown]
# #### Checking how much missing values are present in relevant variables

# %%
(df_cal["price"].isnull().sum(),df_list["weekly_price"].isnull().sum(), df_list["monthly_price"].isnull().sum(), df_list["security_deposit"].isnull().sum(), df_list["cleaning_fee"].isnull().sum())
# Out:
# (459028, 1809, 2300, 1950, 1029)

# %% [markdown]
# #### Getting info for variables

# %%
df_cal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1393570 entries, 0 to 1393569
# Data columns (total 4 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   listing_id  1393570 non-null  int64
#  1   date        1393570 non-null  datetime64[ns]
#  2   available   1393570 non-null  object
#  3   price       934542 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 42.5+ MB

# %%
df_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3816 entries, 0 to 3817
# Data columns (total 93 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3816 non-null   int64
#  1   listing_url                       3816 non-null   object
#  2   scrape_id                         3816 non-null   int64
#  3   last_scraped                      3816 non-null   object
#  4   name                              3816 non-null   object
#  5   summary                           3639 non-null   object
#  6   space                             3248 non-null   object
#  7   description                       3816 non-null   object
#  8   experiences_offered               3816 non-null   object
#  9   neighborhood_overview             2785 non-null   object
#  10  notes                             2211 non-null   object
#  11  transit                           2883 non-null   object
#  12  thumbnail_url                     3496 non-null   object
#  13  medium_url                        3496 non-null   object
#  14  picture_url                       3816 non-null   object
#  15  xl_picture_url                    3496 non-null   object
#  16  host_id                           3816 non-null   int64
#  17  host_url                          3816 non-null   object
#  18  host_name                         3816 non-null   object
#  19  host_since                        3816 non-null   object
#  20  host_location                     3810 non-null   object
#  21  host_about                        2959 non-null   object
#  22  host_response_time                3295 non-null   object
#  23  host_response_rate                3295 non-null   object
#  24  host_acceptance_rate              3045 non-null   object
#  25  host_is_superhost                 3816 non-null   float64
#  26  host_thumbnail_url                3816 non-null   object
#  27  host_picture_url                  3816 non-null   object
#  28  host_neighbourhood                3518 non-null   object
#  29  host_listings_count               3816 non-null   float64
#  30  host_total_listings_count         3816 non-null   int32
#  31  host_verifications                3816 non-null   object
#  32  host_has_profile_pic              3816 non-null   object
#  33  host_identity_verified            3816 non-null   object
#  34  street                            3816 non-null   object
#  35  neighbourhood                     3400 non-null   object
#  36  neighbourhood_cleansed            3816 non-null   object
#  37  neighbourhood_group_cleansed      3816 non-null   object
#  38  city                              3816 non-null   object
#  39  state                             3816 non-null   object
#  40  zipcode                           3809 non-null   object
#  41  market                            3816 non-null   object
#  42  smart_location                    3816 non-null   object
#  43  country_code                      3816 non-null   object
#  44  country                           3816 non-null   object
#  45  latitude                          3816 non-null   float64
#  46  longitude                         3816 non-null   float64
#  47  is_location_exact                 3816 non-null   object
#  48  property_type                     3815 non-null   object
#  49  room_type                         3816 non-null   object
#  50  accommodates                      3816 non-null   int64
#  51  bathrooms                         3800 non-null   float64
#  52  bedrooms                          3810 non-null   float64
#  53  beds                              3815 non-null   float64
#  54  bed_type                          3816 non-null   object
#  55  amenities                         3816 non-null   object
#  56  square_feet                       97 non-null     float64
#  57  price                             3816 non-null   float64
#  58  weekly_price                      2007 non-null   float64
#  59  monthly_price                     1516 non-null   float64
#  60  security_deposit                  1866 non-null   float64
#  61  cleaning_fee                      2787 non-null   float64
#  62  guests_included                   3816 non-null   int64
#  63  extra_people                      3816 non-null   object
#  64  minimum_nights                    3816 non-null   int64
#  65  maximum_nights                    3816 non-null   int64
#  66  calendar_updated                  3816 non-null   object
#  67  has_availability                  3816 non-null   object
#  68  availability_30                   3816 non-null   int64
#  69  availability_60                   3816 non-null   int64
#  70  availability_90                   3816 non-null   int64
#  71  availability_365                  3816 non-null   int64
#  72  calendar_last_scraped             3816 non-null   object
#  73  number_of_reviews                 3816 non-null   int64
#  74  first_review                      3191 non-null   object
#  75  last_review                       3191 non-null   object
#  76  review_scores_rating              3171 non-null   float64
#  77  review_scores_accuracy            3160 non-null   float64
#  78  review_scores_cleanliness         3165 non-null   float64
#  79  review_scores_checkin             3160 non-null   float64
#  80  review_scores_communication       3167 non-null   float64
#  81  review_scores_location            3163 non-null   float64
#  82  review_scores_value               3162 non-null   float64
#  83  requires_license                  3816 non-null   object
#  84  license                           0 non-null      float64
#  85  jurisdiction_names                3816 non-null   object
#  86  instant_bookable                  3816 non-null   int64
#  87  cancellation_policy               3816 non-null   object
#  88  require_guest_profile_picture     3816 non-null   object
#  89  require_guest_phone_verification  3816 non-null   object
#  90  calculated_host_listings_count    3816 non-null   int64
#  91  reviews_per_month                 3191 non-null   float64
#  92  host_response_time_encoded        3295 non-null   float64
# dtypes: float64(23), int32(1), int64(14), object(55)
# memory usage: 2.7+ MB

# %% [markdown]
# #### Remove Outlier

# %%
df_list.drop(int(df_list.loc[df_list["minimum_nights"] == 1000].index[0]), inplace = True)

# %% [markdown]
# #### Define Variables which will be used for correlations

# %%
relevant_var = [
                'instant_bookable'
                ,'review_scores_value' 
                ,'review_scores_rating'
                ,'bathrooms'
                ,'bedrooms'
                ,'beds'
                ,'cleaning_fee'
                ,'extra_people'
                ,'minimum_nights'
                ,'reviews_per_month'
                ,'availability_30'
                ,'availability_60'
                ,'availability_90'
                ,'availability_365'
                ,'security_deposit'
                ,'host_listings_count'
                ,'host_total_listings_count'
                ,'weekly_price'
                ,'monthly_price'
                ,'price'
]

# %% [markdown]
# ## EDA & Evaluate the Results

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Question 1: How much can one expect to pay for staying in an Airbnb accommodation in Seattle?

# %%
df_list["price"].describe()
# Out:
# count    3815.000000
# mean      127.946003
# std        90.261958
# min        20.000000
# 25%        75.000000
# 50%       100.000000
# 75%       150.000000
# max      1000.000000
# Name: price, dtype: float64

# %%
sns.histplot(x='price', data=df_list[relevant_var])
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %% [markdown]
# Description plot: Shows a histogram of the price distribution. Most object that are offered in Seattle are below 200$

# %%
df_list.groupby(['property_type', 'room_type']).price.mean().unstack()
# Out:
# room_type        Entire home/apt  Private room  Shared room
# property_type
# Apartment             132.456140     78.593886    53.372549
# Bed & Breakfast        96.333333    115.969697    30.000000
# Boat                  447.250000    117.500000          NaN
# Bungalow              119.416667     70.000000          NaN
# Cabin                 114.125000     74.400000          NaN
# Camper/RV             137.888889     75.000000   100.000000
# Chalet                135.000000     62.000000          NaN
# Condominium           167.902778     88.166667    75.000000
# Dorm                         NaN           NaN    39.500000
# House                 191.128635     71.609694    42.800000
# Loft                  148.733333    104.555556    25.000000
# Other                 112.833333     81.125000    40.000000
# Tent                   65.000000     50.000000    25.000000
# Townhouse             197.166667     73.483871    36.500000
# Treehouse             200.000000     51.500000          NaN
# Yurt                  100.000000           NaN          NaN

# %%
plt.figure(figsize=(16,16))
ax = sns.heatmap(df_list.groupby(['property_type', 'room_type']).price.mean().unstack(), annot=True, fmt=".0f", cmap="YlGnBu",  linewidths=.5)

# %% [markdown]
# Description Heatmap: Shows the price differences depending on the accommodation type and if the whole accommodation is rented or
# only a room or a shared room is rented. As expected houses and apartments are the more expensive. But the most expensive is renting a boat.

# %%
plt.figure(figsize=(16,22))
ax = sns.heatmap(df_list.loc[~(df_list["bedrooms"] == 0), :].groupby(['neighbourhood_cleansed', 'bedrooms']).price.mean().unstack(), annot=True, fmt=".0f", cmap="YlGnBu",  linewidths=.5)

# %% [markdown]
# Description Heatmap 2: This heatmap shows the price differences depending on the neighboorhood of the accommodation. It shows clearly
# the price differences between the top places like the Pioneer Square and more affordable places like Pinehust. It is also grouped by the number
# of bedrooms that are offered.

# %%
g = sns.FacetGrid(df_list.loc[df_list["property_type"].isin(["Apartment", "House"]), :], col="property_type", height=12)
g.map(sns.histplot, "price")

# %% [markdown]
# Description plot 2: These side by side plots show to histograms of the price of all apartments and houses side by side. The price
# distribution do not differ much by their form but there is a high difference between the upper limit.

# %%
corr = df_list[relevant_var].corr()
kot = corr[corr.apply(lambda x: abs(x)>=0)]
sns.heatmap(kot, annot = True, fmt = '.2f', cmap = 'Blues', center = 0)
plt.rcParams["figure.figsize"] = (20,15)
plt.title('Features Correlation');
plt.xticks(rotation = 90);

# %% [markdown]
# The above correlation plot shows the strongest correlations with the price. Without a suprise factors like the size of the accommodation which can be
# taken by the amount of bedrooms or the number of beds correlate stronger with the price.

# %%
df_list[['host_response_time_encoded', 'price']].corr()
# Out:
#                             host_response_time_encoded     price
# host_response_time_encoded                    1.000000  0.082672
# price                                         0.082672  1.000000

# %%
df_list[['host_is_superhost', 'price']].corr()
# Out:
#                    host_is_superhost     price
# host_is_superhost           1.000000  0.012305
# price                       0.012305  1.000000

# %% [markdown]
# It seems that superhost status or the response time of the host have not much correlation with the price.

# %% [markdown]
# ### Question 2: When is the best time to get Airbnb accommodation

# %%
df_cal.groupby(df_cal['date'].map(lambda x: x.year)).size()
# Out:
# date
# 2016    1385934
# 2017       7636
# dtype: int64

# %%
df_cal['date'].groupby([df_cal.date.dt.year, df_cal.date.dt.month]).agg('count')
# Out:
# date  date
# 2016  1       106904
#       2       110722
#       3       118358
#       4       114540
#       5       118358
#       6       114540
#       7       118358
#       8       118358
#       9       114540
#       10      118358
#       11      114540
#       12      118358
# 2017  1         7636
# Name: date, dtype: int64

# %% [markdown]
# It does not make sense to compare the data of 2017 to 2016 because only one month is present in 2016

# %%
df_cal_2016 = df_cal[df_cal.date.dt.year == 2016]
month = df_cal.date.dt.month

# %%
sns.countplot(data = df_cal, x = month, hue = 'available');
plt.title('Occupation in 2016');

# %% [markdown]
# Description Time Series Plot: This plot shows the total number of available and taken nights for all offered accommodations for the year 2016.
# From this plot it is clear that for example the month December has more nights available to book then July or August, which can be considered as high demand months.

# %%
df_cal_2016['date'].groupby([df_cal.date.dt.year, df_cal.date.dt.month, df_cal.available ]).agg('count')
# Out:
# date  date  available
# 2016  1     f            47665
#             t            59239
#       2     f            37401
#             t            73321
#       3     f            34420
#             t            83938
#       4     f            38503
#             t            76037
#       5     f            38387
#             t            79971
#       6     f            37296
#             t            77244
#       7     f            44136
#             t            74222
#       8     f            42011
#             t            76347
#       9     f            37294
#             t            77246
#       10    f            35920
#             t            82438
#       11    f            32760
#             t            81780
#       12    f            31297
#             t            87061
# Name: date, dtype: int64

# %%
year_group_available = df_cal_2016['date'].groupby([df_cal.date.dt.year, df_cal.date.dt.month, df_cal.available ]).agg('count')

# %%
group_pcts = year_group_available.groupby(level=1).apply(lambda x: 100 * x / float(x.sum()))
group_pcts
# Out:
# date  date  available
# 2016  1     f            44.586732
#             t            55.413268
#       2     f            33.779195
#             t            66.220805
#       3     f            29.081262
#             t            70.918738
#       4     f            33.615331
#             t            66.384669
#       5     f            32.432958
#             t            67.567042
#       6     f            32.561551
#             t            67.438449
#       7     f            37.290255
#             t            62.709745
#       8     f            35.494855
#             t            64.505145
#       9     f            32.559804
#             t            67.440196
#       10    f            30.348603
#             t            69.651397
#       11    f            28.601362
#             t            71.398638
#       12    f            26.442657
#             t            73.557343
# Name: date, dtype: float64

# %%
sns.histplot(x='availability_365', data=df_list[relevant_var])
# Out:
# <AxesSubplot:xlabel='availability_365', ylabel='Count'>

# %% [markdown]
# The above plot shows a histogram that shows the distribution of the availability of accommodation over all listings. From it is clear that only a view accommodations are booked more than 100 days a year. The most accomodations are only booked viewer than 10 days a year.

# %% [markdown]
# #### Checking the most offered accommodation types

# %%
df_list['property_type'].value_counts().index

sns.countplot(data = df_list, x = 'property_type',  color=sns.color_palette()[0])
plt.rcParams["figure.figsize"] = (18,12)
plt.ylabel('Number of listings')
plt.xlabel('Listing Type')
plt.xticks(rotation = 45)
plt.title('Property_types', );

# %% [markdown]
# From this Barplot above it is clear that the most offered accommodations are houses and apartments.

# %%
df_cal_2016[['date','price']].groupby([df_cal.date.dt.year, df_cal.date.dt.month, df_cal.available ]).agg({'price': ['mean', 'std']})
# Out:
#                           price
#                            mean         std
# date date available
# 2016 1    f                 NaN         NaN
#           t          121.568409   86.900024
#      2    f                 NaN         NaN
#           t          124.293927   91.550076
#      3    f                 NaN         NaN
#           t          128.644488   94.371410
#      4    f                 NaN         NaN
#           t          135.097005   98.232098
#      5    f                 NaN         NaN
#           t          139.538183  102.863280
#      6    f                 NaN         NaN
#           t          147.473137  112.481803
#      7    f                 NaN         NaN
#           t          152.094150  120.078098
#      8    f                 NaN         NaN
#           t          150.656594  118.754189
#      9    f                 NaN         NaN
#           t          143.255949  108.804290
#      10   f                 NaN         NaN
#           t          137.031939  104.491505
#      11   f                 NaN         NaN
#           t          135.688738  104.264654
#      12   f                 NaN         NaN
#           t          137.251835  105.101659

# %% [markdown]
# The above table shows how much on average one can expect to pay for accomondations grouped by month and how high the standard deviation is for these months for the price.

# %% [markdown]
# ### Question 3: How much Revenue one can expect when offering a accommodation on Airbnb living in Seattle?

# %%
df_cal.head()
# Out:
#    listing_id       date available  price
# 0      241032 2016-01-04         t   85.0
# 1      241032 2016-01-05         t   85.0
# 2      241032 2016-01-06         f    NaN
# 3      241032 2016-01-07         f    NaN
# 4      241032 2016-01-08         f    NaN

# %%
df_cal.groupby(["listing_id"]).agg({"price": 'mean'})
# Out:
#                  price
# listing_id
# 3335        120.000000
# 4291         82.000000
# 5682         53.944984
# 6606         92.849315
# 7369         85.000000
# ...                ...
# 10332096     40.000000
# 10334184    120.000000
# 10339144           NaN
# 10339145    237.904110
# 10340165     43.000000
#
# [3818 rows x 1 columns]

# %%
list_taken = df_cal.groupby(["listing_id", "available"]).size()#.unstack()
list_taken
# Out:
# listing_id  available
# 3335        f             56
#             t            309
# 4291        t            365
# 5682        f             56
#             t            309
#                         ...
# 10334184    t            361
# 10339144    f            365
# 10339145    t            365
# 10340165    f              7
#             t            358
# Length: 6863, dtype: int64

# %%
list_taken = list_taken.reset_index()

# %%
list_taken.loc[list_taken["available"] == 'f']
# Out:
#       listing_id available    0
# 0           3335         f   56
# 3           5682         f   56
# 6           7369         f  312
# 9           9460         f  308
# 11          9531         f  185
# ...          ...       ...  ...
# 6852    10319529         f  364
# 6854    10331249         f   11
# 6857    10334184         f    4
# 6859    10339144         f  365
# 6861    10340165         f    7
#
# [3140 rows x 3 columns]

# %%
df_list[["id", "price"]]
# Out:
#             id  price
# 0       241032   85.0
# 1       953595  150.0
# 2      3308979  975.0
# 3      7421966  100.0
# 4       278830  450.0
# ...        ...    ...
# 3813   8101950  359.0
# 3814   8902327   79.0
# 3815  10267360   93.0
# 3816   9604740   99.0
# 3817  10208623   87.0
#
# [3815 rows x 2 columns]

# %%
taken_listings_price = pd.merge(list_taken.loc[list_taken["available"] == 'f'], df_list[["id", "price"]], how = "inner", left_on = "listing_id", right_on = "id" )
taken_listings_price
# Out:
#       listing_id available    0        id  price
# 0           3335         f   56      3335  120.0
# 1           5682         f   56      5682   48.0
# 2           7369         f  312      7369   85.0
# 3           9460         f  308      9460   99.0
# 4           9531         f  185      9531  165.0
# ...          ...       ...  ...       ...    ...
# 3132    10319529         f  364  10319529   49.0
# 3133    10331249         f   11  10331249   45.0
# 3134    10334184         f    4  10334184  120.0
# 3135    10339144         f  365  10339144   60.0
# 3136    10340165         f    7  10340165   43.0
#
# [3137 rows x 5 columns]

# %%
taken_listings_price["revenue_listings"] = taken_listings_price[0] * taken_listings_price["price"]
taken_listings_price["revenue_listings"]
# Out:
# 0        6720.0
# 1        2688.0
# 2       26520.0
# 3       30492.0
# 4       30525.0
#          ...
# 3132    17836.0
# 3133      495.0
# 3134      480.0
# 3135    21900.0
# 3136      301.0
# Name: revenue_listings, Length: 3137, dtype: float64

# %%
taken_listings_price
# Out:
#       listing_id available    0        id  price  revenue_listings
# 0           3335         f   56      3335  120.0            6720.0
# 1           5682         f   56      5682   48.0            2688.0
# 2           7369         f  312      7369   85.0           26520.0
# 3           9460         f  308      9460   99.0           30492.0
# 4           9531         f  185      9531  165.0           30525.0
# ...          ...       ...  ...       ...    ...               ...
# 3132    10319529         f  364  10319529   49.0           17836.0
# 3133    10331249         f   11  10331249   45.0             495.0
# 3134    10334184         f    4  10334184  120.0             480.0
# 3135    10339144         f  365  10339144   60.0           21900.0
# 3136    10340165         f    7  10340165   43.0             301.0
#
# [3137 rows x 6 columns]

# %%
taken_listings_price["revenue_listings"].describe()
# Out:
# count      3137.000000
# mean      18905.196685
# std       23613.991762
# min          39.000000
# 25%        2175.000000
# 50%       11872.000000
# 75%       27225.000000
# max      364635.000000
# Name: revenue_listings, dtype: float64

# %%
sns.histplot(x='revenue_listings', data=taken_listings_price)
# Out:
# <AxesSubplot:xlabel='revenue_listings', ylabel='Count'>

# %% [markdown]
# The above plot shows the revenue distribution of all hosts for the yeas 2016 in Seattle. It shows that the majority of the host did make less then 20000$.
